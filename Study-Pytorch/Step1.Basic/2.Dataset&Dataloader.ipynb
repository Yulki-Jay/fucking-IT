# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
figure = plt.figure(figsize=(4, 4))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    sample_idx = torch.randint(len(training_data), (1,)).item()
     # get the image and label corresponding to the random index
    if i == 1:
        print(f"sample_idx: {sample_idx}")
    img,label = training_data[sample_idx]
    print(f"img.shape: {img.shape}, label: {label}, label_name: {labels_map[label]}")
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
    
plt.show()
# Out:
# sample_idx: 25967
# img.shape: torch.Size([1, 28, 28]), label: 5, label_name: Sandal
# img.shape: torch.Size([1, 28, 28]), label: 9, label_name: Ankle Boot
# img.shape: torch.Size([1, 28, 28]), label: 9, label_name: Ankle Boot
# img.shape: torch.Size([1, 28, 28]), label: 0, label_name: T-Shirt
# img.shape: torch.Size([1, 28, 28]), label: 1, label_name: Trouser
# img.shape: torch.Size([1, 28, 28]), label: 2, label_name: Pullover
# img.shape: torch.Size([1, 28, 28]), label: 1, label_name: Trouser
# img.shape: torch.Size([1, 28, 28]), label: 5, label_name: Sandal
# img.shape: torch.Size([1, 28, 28]), label: 9, label_name: Ankle Boot

# %%
import os
import pandas as pd
from torchvision.io import decode_image

class CustomImageDataset(Dataset):
    def __init__(self,annotions_file,img_dir,transform=None,target_transform=None):
        self.img_labels = pd.read_csv(annotions_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform
    def __len__(self):
        return len(self.img_labels)
    
    def __getitem__(self,idx):
        img_path = os.path.join(self.img_dir,self.img_labels.iloc[idx,0])
        image = decode_image(img_path)
        label = self.img_labels.iloc[idx,1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(training_data, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
train_features,train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze() 
# squeeze() 的作用是移除张量中所有大小为 1 的维度。
# unsqueeze(dim)在 dim 位置添加大小为 1 的维度
plt.imshow(img,cmap="gray")
plt.show()
print(f"Label: {train_labels[0]}")
# Out:
# Feature batch shape: torch.Size([64, 1, 28, 28])
# Labels batch shape: torch.Size([64])
# Label: 9
